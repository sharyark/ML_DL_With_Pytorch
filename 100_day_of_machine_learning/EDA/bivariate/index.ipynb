# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('titanic.csv')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
tips.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2

# %%
# scatter plot (numerical,numerical)
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# multivariate
sns.scatterplot(x='total_bill', y='tip', data=tips,hue='sex')
plt.show()

# %%
# barplot numerical vs categorcal
sns.barplot(x='Pclass', y='Age', data=titanic)
plt.show()

# %%
# heatmap
# this is for analyse categorical dataset
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
# pairplot it detect all numerical columns in data and plot acordingly
sns.pairplot(iris)

# %%
# some practice work

# %%
# groupby function group data base on columns 
# Survival rate based on gender
survival_by_gender = titanic.groupby('Sex')['Survived'].sum()

# # Survival rate based on passenger class
survival_by_class = titanic.groupby('Pclass')

# # Survival rate based on embarkation point
# survival_by_embarked = data.groupby('Embarked')['Survived'].mean()

# # Survival rate based on number of siblings/spouses aboard
# survival_by_sibsp = data.groupby('SibSp')['Survived'].mean()

# # Survival rate based on number of parents/children aboard
# survival_by_parch = data.groupby('Parch')['Survived'].mean()

# Display the results
# print("Survival Rate by Gender:\n", survival_by_gender)
print("\nSurvival Rate by Passenger Class:\n", survival_by_class)
# print("\nSurvival Rate by Embarkation Point:\n", survival_by_embarked)
# print("\nSurvival Rate by Siblings/Spouses Aboard:\n", survival_by_sibsp)
# print("\nSurvival Rate by Parents/Children Aboard:\n", survival_by_parch)
# Out:
# Survival Rate by Passenger Class:
# ...

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# after groupby we can perform these functionality like sum size groups 
# here is example of goupby_obj.groups --> it return dictionary which key is group name and value is how many row are in that group
# survival_by_class.groups[2].values
survival_by_class.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
# List of IDs
ids = [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 
       117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 
       181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 
       234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 
       303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 
       346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 
       418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, 466, 472, 
       473, 476, 481, 506, 516, 518, 526, 529, 530, 535, 543, 546, 547, 549, 
       551, 562, 570, 576, 580, 582, 586, 594, 596, 600, 608, 615, 618, 619, 
       626, 635, 637, 651, 655, 658, 665, 666, 670, 672, 673, 674, 684, 685, 
       695, 705, 706, 714, 717, 720, 722, 723, 726, 728, 732, 733, 734, 747, 
       750, 754, 755, 757, 772, 774, 791, 795, 800, 801, 808, 812, 817, 827, 
       831, 841, 848, 854, 861, 864, 865, 866, 874, 880, 883, 886]

# Filter the rows
# filtered_data = titanic[titanic['PassengerId'].isin(ids)]
filtered_data = titanic.loc[ids]
# Display the filtered data
filtered_data
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
mask = titanic[titanic['Pclass'] >= 2]

# %%
len(mask)
# Out:
# 675

# %%
len(obj)
# Out:
# 891

# %%
len(titanic['Pclass'])
# Out:
# 891
